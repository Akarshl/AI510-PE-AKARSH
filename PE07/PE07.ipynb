# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import random
import math
import matplotlib.pyplot as plt

# %%
# Load and preprocess MNIST
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1)).astype("float32") / 255
test_images  = test_images.reshape((10000, 28, 28, 1)).astype("float32") / 255
train_labels_cat = tf.keras.utils.to_categorical(train_labels, 10)
test_labels_cat  = tf.keras.utils.to_categorical(test_labels, 10)

# %%
# Simple CNN model (unchanged structure)
model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation="relu", input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation="relu"),
    layers.Dense(10, activation="softmax")
])
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
model.fit(train_images, train_labels_cat, epochs=1, batch_size=64, validation_split=0.1)
# Out:
# 2025-08-24 01:33:43.933884: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 169344000 exceeds 10% of free system memory.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 14s 16ms/step - accuracy: 0.9371 - loss: 0.2190 - val_accuracy: 0.9793 - val_loss: 0.0759

# %%
# Reward matrix and Q-table for RL (kept as-is)
R = np.array([[0, 1], [1, 0]])
Q = np.zeros_like(R, dtype=float)
gamma = 0.8

# %%
# Logistic sigmoid function for CRLMM-inspired adjustment (kept for completeness)
def sigmoid(x): 
    return 1 / (1 + np.exp(-x))

# %%
# Predict function + CRLMM update, now returning reward so we can tally results
def predict_and_reward(image, true_label):
    # verbose=1 to show the "1/1 ... step" lines like in your expected output
    pred_probs = model.predict(image[np.newaxis, ...], verbose=1)[0]
    action = int(np.argmax(pred_probs))
    reward = 1 if action == int(true_label) else -1
    # Simple Q update (unchanged logic)
    Q[0, action % 2] += gamma * reward
    print(f"Predicted: {action}, True: {int(true_label)}, Reward: {reward}, Q-table: {Q}")
    return reward

# %%
# ---- Simulation with tracking ----
num_tests = 100  # run at least 100 samples
correct = 0
incorrect = 0

for _ in range(num_tests):
    idx = random.randint(0, len(test_images) - 1)
    r = predict_and_reward(test_images[idx], test_labels[idx])
    if r == 1:
        correct += 1
    else:
        incorrect += 1

accuracy = correct / num_tests
print(f"\nCorrect: {correct}, Incorrect: {incorrect}, Accuracy: {accuracy:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Predicted: 0, True: 0, Reward: 1, Q-table: [[0.8 0. ]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Predicted: 5, True: 5, Reward: 1, Q-table: [[0.8 0.8]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted: 5, True: 5, Reward: 1, Q-table: [[0.8 1.6]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Predicted: 0, True: 0, Reward: 1, Q-table: [[1.6 1.6]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Predicted: 1, True: 1, Reward: 1, Q-table: [[1.6 2.4]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Predicted: 1, True: 1, Reward: 1, Q-table: [[1.6 3.2]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Predicted: 7, True: 7, Reward: 1, Q-table: [[1.6 4. ]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted: 8, True: 8, Reward: 1, Q-table: [[2.4 4. ]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Predicted: 3, True: 3, Reward: 1, Q-table: [[2.4 4.8]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 1, True: 1, Reward: 1, Q-table: [[2.4 5.6]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted: 0, True: 0, Reward: 1, Q-table: [[3.2 5.6]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted: 6, True: 6, Reward: 1, Q-table: [[4.  5.6]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted: 1, True: 1, Reward: 1, Q-table: [[4.  6.4]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted: 3, True: 3, Reward: 1, Q-table: [[4.  7.2]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted: 3, True: 3, Reward: 1, Q-table: [[4. 8.]
#  [0. 0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Predicted: 6, True: 6, Reward: 1, Q-table: [[4.8 8. ]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Predicted: 6, True: 6, Reward: 1, Q-table: [[5.6 8. ]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted: 2, True: 2, Reward: 1, Q-table: [[6.4 8. ]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Predicted: 5, True: 5, Reward: 1, Q-table: [[6.4 8.8]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Predicted: 2, True: 2, Reward: 1, Q-table: [[7.2 8.8]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Predicted: 7, True: 7, Reward: 1, Q-table: [[7.2 9.6]
#  [0.  0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Predicted: 9, True: 9, Reward: 1, Q-table: [[ 7.2 10.4]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted: 4, True: 4, Reward: 1, Q-table: [[ 8.  10.4]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Predicted: 4, True: 4, Reward: 1, Q-table: [[ 8.8 10.4]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted: 9, True: 9, Reward: 1, Q-table: [[ 8.8 11.2]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted: 6, True: 6, Reward: 1, Q-table: [[ 9.6 11.2]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 6, True: 6, Reward: 1, Q-table: [[10.4 11.2]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Predicted: 3, True: 3, Reward: 1, Q-table: [[10.4 12. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Predicted: 8, True: 8, Reward: 1, Q-table: [[11.2 12. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 6, True: 6, Reward: 1, Q-table: [[12. 12.]
#  [ 0.  0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 9, True: 4, Reward: -1, Q-table: [[12.  11.2]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 2, True: 2, Reward: 1, Q-table: [[12.8 11.2]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted: 9, True: 9, Reward: 1, Q-table: [[12.8 12. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Predicted: 8, True: 8, Reward: 1, Q-table: [[13.6 12. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Predicted: 6, True: 6, Reward: 1, Q-table: [[14.4 12. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Predicted: 9, True: 9, Reward: 1, Q-table: [[14.4 12.8]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Predicted: 6, True: 6, Reward: 1, Q-table: [[15.2 12.8]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 7, True: 7, Reward: 1, Q-table: [[15.2 13.6]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted: 7, True: 7, Reward: 1, Q-table: [[15.2 14.4]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Predicted: 3, True: 3, Reward: 1, Q-table: [[15.2 15.2]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Predicted: 1, True: 1, Reward: 1, Q-table: [[15.2 16. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted: 8, True: 8, Reward: 1, Q-table: [[16. 16.]
#  [ 0.  0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted: 2, True: 2, Reward: 1, Q-table: [[16.8 16. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 8, True: 8, Reward: 1, Q-table: [[17.6 16. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted: 8, True: 8, Reward: 1, Q-table: [[18.4 16. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Predicted: 1, True: 1, Reward: 1, Q-table: [[18.4 16.8]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 0, True: 0, Reward: 1, Q-table: [[19.2 16.8]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted: 2, True: 2, Reward: 1, Q-table: [[20.  16.8]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted: 1, True: 1, Reward: 1, Q-table: [[20.  17.6]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted: 4, True: 4, Reward: 1, Q-table: [[20.8 17.6]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 6, True: 6, Reward: 1, Q-table: [[21.6 17.6]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Predicted: 5, True: 5, Reward: 1, Q-table: [[21.6 18.4]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted: 3, True: 3, Reward: 1, Q-table: [[21.6 19.2]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Predicted: 9, True: 9, Reward: 1, Q-table: [[21.6 20. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted: 7, True: 7, Reward: 1, Q-table: [[21.6 20.8]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 1, True: 1, Reward: 1, Q-table: [[21.6 21.6]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predicted: 6, True: 6, Reward: 1, Q-table: [[22.4 21.6]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted: 4, True: 4, Reward: 1, Q-table: [[23.2 21.6]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted: 7, True: 7, Reward: 1, Q-table: [[23.2 22.4]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Predicted: 7, True: 7, Reward: 1, Q-table: [[23.2 23.2]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted: 5, True: 5, Reward: 1, Q-table: [[23.2 24. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 2, True: 2, Reward: 1, Q-table: [[24. 24.]
#  [ 0.  0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Predicted: 4, True: 4, Reward: 1, Q-table: [[24.8 24. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 6, True: 6, Reward: 1, Q-table: [[25.6 24. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 0, True: 0, Reward: 1, Q-table: [[26.4 24. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted: 0, True: 0, Reward: 1, Q-table: [[27.2 24. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted: 2, True: 2, Reward: 1, Q-table: [[28. 24.]
#  [ 0.  0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Predicted: 7, True: 7, Reward: 1, Q-table: [[28.  24.8]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Predicted: 1, True: 1, Reward: 1, Q-table: [[28.  25.6]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted: 7, True: 7, Reward: 1, Q-table: [[28.  26.4]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted: 1, True: 1, Reward: 1, Q-table: [[28.  27.2]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted: 1, True: 1, Reward: 1, Q-table: [[28. 28.]
#  [ 0.  0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Predicted: 7, True: 7, Reward: 1, Q-table: [[28.  28.8]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 1, True: 2, Reward: -1, Q-table: [[28. 28.]
#  [ 0.  0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Predicted: 1, True: 1, Reward: 1, Q-table: [[28.  28.8]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted: 3, True: 3, Reward: 1, Q-table: [[28.  29.6]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted: 2, True: 2, Reward: 1, Q-table: [[28.8 29.6]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Predicted: 4, True: 4, Reward: 1, Q-table: [[29.6 29.6]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted: 4, True: 4, Reward: 1, Q-table: [[30.4 29.6]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 7, True: 7, Reward: 1, Q-table: [[30.4 30.4]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 5, True: 5, Reward: 1, Q-table: [[30.4 31.2]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted: 0, True: 0, Reward: 1, Q-table: [[31.2 31.2]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Predicted: 2, True: 2, Reward: 1, Q-table: [[32.  31.2]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Predicted: 1, True: 1, Reward: 1, Q-table: [[32. 32.]
#  [ 0.  0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Predicted: 0, True: 0, Reward: 1, Q-table: [[32.8 32. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 8, True: 8, Reward: 1, Q-table: [[33.6 32. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Predicted: 2, True: 2, Reward: 1, Q-table: [[34.4 32. ]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Predicted: 3, True: 3, Reward: 1, Q-table: [[34.4 32.8]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Predicted: 6, True: 6, Reward: 1, Q-table: [[35.2 32.8]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 4, True: 4, Reward: 1, Q-table: [[36.  32.8]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Predicted: 4, True: 4, Reward: 1, Q-table: [[36.8 32.8]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 6, True: 6, Reward: 1, Q-table: [[37.6 32.8]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Predicted: 6, True: 6, Reward: 1, Q-table: [[38.4 32.8]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted: 0, True: 0, Reward: 1, Q-table: [[39.2 32.8]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Predicted: 9, True: 9, Reward: 1, Q-table: [[39.2 33.6]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Predicted: 1, True: 1, Reward: 1, Q-table: [[39.2 34.4]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Predicted: 4, True: 4, Reward: 1, Q-table: [[40.  34.4]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Predicted: 6, True: 6, Reward: 1, Q-table: [[40.8 34.4]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted: 5, True: 5, Reward: 1, Q-table: [[40.8 35.2]
#  [ 0.   0. ]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Predicted: 4, True: 4, Reward: 1, Q-table: [[41.6 35.2]
#  [ 0.   0. ]]
#
# Correct: 98, Incorrect: 2, Accuracy: 0.98
